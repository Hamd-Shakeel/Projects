# %%
import pandas as pd
import requests

# %%
requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b48351e48e9e95b7150caad031df2af6&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b48351e48e9e95b7150caad031df2af6&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 127.465,
#    'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.711,
#    'vote_count': 25431},
#   {'adult': False,
#    'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 127.465,
#   'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.711,
#   'vote_count': 25431},
#  {'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
temp_df=pd.DataFrame(response.json()['results'])[['id','original_title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df
# Out:
#         id                                 original_title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5    19404                   दिलवाले दुल्हनिया ले जायेंगे
# 6      129                                       千と千尋の神隠し
# 7      155                                The Dark Knight
# 8   496243                                            기생충
# 9      497                                 The Green Mile
# 10  372058                                          君の名は。
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                Il buono, il brutto, il cattivo
# ...

# %%
temp_df.head(2)
# Out:
#     id            original_title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     127.465
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     112.113
#
#    vote_average  vote_count
# 0         8.711       25431
# 1         8.708       19358

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,457):
    response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b48351e48e9e95b7150caad031df2af6&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','original_title','overview','release_date','popularity','vote_average','vote_count']]
    df=df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#          id                 original_title  \
# 0       278       The Shawshank Redemption
# 1       238                  The Godfather
# 2       240          The Godfather Part II
# 3       424               Schindler's List
# 4       389                   12 Angry Men
# ...     ...                            ...
# 9115  10870                     Les Dalton
# 9116  74849  The Star Wars Holiday Special
# 9117  12142              Alone in the Dark
# 9118  13805                 Disaster Movie
# 9119   5491              Battlefield Earth
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...

# %%
df.head(2)
# Out:
#     id            original_title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     127.465
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     112.113
#
#    vote_average  vote_count
# 0         8.711       25431
# 1         8.708       19358

# %%
df.to_csv('Movies.csv')
